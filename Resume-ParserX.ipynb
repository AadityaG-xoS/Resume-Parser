# %%
# !pip install PyMuPDF pdfminer.six python-docx spacy nltk ipywidgets

# !python -m spacy download en_core_web_sm


import fitz  
from pdfminer.high_level import extract_text
from docx import Document
import spacy
import re
import json
import os
import nltk
from ipywidgets import FileUpload, Output
from IPython.display import display

nltk.download('punkt')

def process_pdf(file_path):
    text = ""
    with fitz.open(file_path) as doc:
        for page in doc:
            text += page.get_text()
    return text

def process_docx(file_path):
    doc = Document(file_path)
    text = "\n".join([para.text for para in doc.paragraphs])
    return text

def process_txt(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()
    return text

def process_file(file_path):
    if file_path.endswith('.pdf'):
        return process_pdf(file_path)
    elif file_path.endswith('.docx'):
        return process_docx(file_path)
    elif file_path.endswith('.txt'):
        return process_txt(file_path)
    else:
        raise ValueError("Unsupported file format")

nlp = spacy.load("en_core_web_sm")


def extract_name(text):
    doc = nlp(text)
    for ent in doc.ents:
        if ent.label_ == "PERSON":
            return ent.text
    return None

def extract_contact_info(text):
    phone_pattern = re.compile(r'\b\d{10}\b')
    email_pattern = re.compile(r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b')
    phone = phone_pattern.search(text)
    email = email_pattern.search(text)
    return phone.group() if phone else None, email.group() if email else None

def extract_education(text):
    education_keywords = ['school', 'college', 'university', 'institute', 'academy', 'degree', 'bachelor', 'master', 'phd']
    sentences = nltk.sent_tokenize(text)
    education = []
    for sent in sentences:
        if any(keyword in sent.lower() for keyword in education_keywords):
            education.append(sent.strip())
    return education

def extract_experience(text):
    experience_keywords = ['experience', 'worked', 'employed', 'job', 'position', 'role', 'responsibility']
    sentences = nltk.sent_tokenize(text)
    experience = []
    for sent in sentences:
        if any(keyword in sent.lower() for keyword in experience_keywords):
            experience.append(sent.strip())
    return experience

def extract_skills(text):
    skills = ["Python", "NLP", "Machine Learning", "Data Analysis", "Project Management", "Leadership"]
    extracted_skills = [skill for skill in skills if skill in text]
    return extracted_skills

def extract_data(text):
    name = extract_name(text)
    phone, email = extract_contact_info(text)
    education = extract_education(text)
    experience = extract_experience(text)
    skills = extract_skills(text)

    return {
        "name": name,
        "phone": phone,
        "email": email,
        "education": education,
        "experience": experience,
        "skills": skills
    }

def generate_output(data):
    output = ""
    output += f"{data['name']}\n"
    output += f"{data['email']}\n"
    output += f"{data['phone']}\n\n"

    output += "Education:\n"
    for edu in data['education']:
        output += f"- {edu}\n"

    output += "\nExperience:\n"
    for exp in data['experience']:
        output += f"- {exp}\n"

    output += "\nSkills:\n"
    for skill in data['skills']:
        output += f"- {skill}\n"

    return output

def upload_and_process(change):
    for file_name, file_info in uploader.value.items():
        with open(file_name, 'wb') as f:
            f.write(file_info['content'])
        text = process_file(file_name)
        data = extract_data(text)
        formatted_output = generate_output(data)
        
        out.clear_output()
        with out:
            print(f"Parsed data for {file_name}:\n")
            print(formatted_output)
            print("\n" + "="*50 + "\n")


uploader = FileUpload(accept='.pdf,.docx,.txt', multiple=False)
uploader.observe(upload_and_process, names='value')

out = Output()

display(uploader, out)
# Out:
# Requirement already satisfied: PyMuPDF in c:\users\aaditya g\anaconda3\lib\site-packages (1.24.7)
# Requirement already satisfied: pdfminer.six in c:\users\aaditya g\anaconda3\lib\site-packages (20240706)
# Requirement already satisfied: python-docx in c:\users\aaditya g\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: spacy in c:\users\aaditya g\anaconda3\lib\site-packages (3.7.5)
# Requirement already satisfied: nltk in c:\users\aaditya g\anaconda3\lib\site-packages (3.6.5)
# Requirement already satisfied: ipywidgets in c:\users\aaditya g\anaconda3\lib\site-packages (7.6.5)
# Requirement already satisfied: PyMuPDFb==1.24.6 in c:\users\aaditya g\anaconda3\lib\site-packages (from PyMuPDF) (1.24.6)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from pdfminer.six) (42.0.8)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from pdfminer.six) (2.0.4)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from python-docx) (4.6.3)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from python-docx) (4.12.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy) (21.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy) (8.2.5)
# Requirement already satisfied: jinja2 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy) (2.11.3)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy) (1.20.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy) (2.8.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: setuptools in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy) (58.0.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy) (2.26.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy) (4.62.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy) (0.12.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy) (3.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: click in c:\users\aaditya g\anaconda3\lib\site-packages (from nltk) (8.0.3)
# Requirement already satisfied: joblib in c:\users\aaditya g\anaconda3\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\aaditya g\anaconda3\lib\site-packages (from nltk) (2021.8.3)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from ipywidgets) (5.1.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from ipywidgets) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from ipywidgets) (3.5.1)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\aaditya g\anaconda3\lib\site-packages (from ipywidgets) (6.4.1)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\aaditya g\anaconda3\lib\site-packages (from ipywidgets) (5.1.0)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from ipywidgets) (7.29.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\aaditya g\anaconda3\lib\site-packages (from cryptography>=36.0.0->pdfminer.six) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\aaditya g\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six) (2.20)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.2)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\aaditya g\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.4.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1.12)
# Requirement already satisfied: pickleshare in c:\users\aaditya g\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (3.0.20)
# Requirement already satisfied: decorator in c:\users\aaditya g\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (5.1.0)
# Requirement already satisfied: backcall in c:\users\aaditya g\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: colorama in c:\users\aaditya g\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.4.6)
# Requirement already satisfied: jedi>=0.16 in c:\users\aaditya g\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.18.0)
# Requirement already satisfied: pygments in c:\users\aaditya g\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (2.18.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\aaditya g\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (22.2.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\aaditya g\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (4.8.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (228)
# Requirement already satisfied: language-data>=1.2 in c:\users\aaditya g\anaconda3\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\aaditya g\anaconda3\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\aaditya g\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (21.2.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (1.16.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\aaditya g\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (3.0.4)
# Requirement already satisfied: wcwidth in c:\users\aaditya g\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\aaditya g\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.20.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aaditya g\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aaditya g\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\aaditya g\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\aaditya g\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\aaditya g\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\aaditya g\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\aaditya g\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.0.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.18.1)
# Requirement already satisfied: wrapt in c:\users\aaditya g\anaconda3\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.12.1)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\aaditya g\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets) (6.4.5)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.8.0)
# Requirement already satisfied: prometheus-client in c:\users\aaditya g\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.11.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\aaditya g\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.9.4)
# Requirement already satisfied: nbconvert in c:\users\aaditya g\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (6.1.0)
# Requirement already satisfied: argon2-cffi in c:\users\aaditya g\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (20.1.0)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\aaditya g\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.7)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\aaditya g\anaconda3\lib\site-packages (from jinja2->spacy) (1.1.1)
# Requirement already satisfied: bleach in c:\users\aaditya g\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (4.0.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\aaditya g\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.1.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.3)
# Requirement already satisfied: defusedxml in c:\users\aaditya g\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.7.1)
# Requirement already satisfied: testpath in c:\users\aaditya g\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\aaditya g\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.4.3)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\aaditya g\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\aaditya g\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.4)
# Requirement already satisfied: nest-asyncio in c:\users\aaditya g\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.5.1)
# Requirement already satisfied: async-generator in c:\users\aaditya g\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.10)
# Requirement already satisfied: webencodings in c:\users\aaditya g\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.1)
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\aaditya g\anaconda3\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.5)
# Requirement already satisfied: jinja2 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.11.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.20.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.12.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.26.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (21.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.0)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: setuptools in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (58.0.4)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.62.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\aaditya g\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.8.2)
# Requirement already satisfied: language-data>=1.2 in c:\users\aaditya g\anaconda3\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\aaditya g\anaconda3\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\aaditya g\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\aaditya g\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.12.2)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\aaditya g\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.20.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aaditya g\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\aaditya g\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aaditya g\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.2)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\aaditya g\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\aaditya g\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: colorama in c:\users\aaditya g\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.0.3)
# Requirement already satisfied: rich>=10.11.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (13.7.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\aaditya g\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.2)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\aaditya g\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (7.0.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\aaditya g\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.18.1)
# Requirement already satisfied: wrapt in c:\users\aaditya g\anaconda3\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.12.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\aaditya g\anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# [nltk_data] Downloading package punkt to C:\Users\Aaditya
# [nltk_data]     G\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# FileUpload(value={}, accept='.pdf,.docx,.txt', description='Upload')
# Output()
